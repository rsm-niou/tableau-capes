# %%
import pandas as pd
import numpy as np

# %%
capes_dat = pd.read_csv('data/capes_data.csv')
capes_dat
# Out:
#                      Instructor  \
# 0      Butler Elizabeth Annette
# 1      Butler Elizabeth Annette
# 2      Jones Ian William Nasser
# 3              Shtienberg Gilad
# 4          Braswell Geoffrey E.
# ...                         ...
# 63358                   Li Huai
# 63359          Guerrero Raul M.
# 63360          Mangolte Babette
# 63361     Holland Nicole Murphy
# 63362   Michaelis Danielle Ruth
#
#                                                Course Quarter  \
# 0         AAS 10 - Intro/African-American Studies (A)    SP23
# 1                  AAS 170 - Legacies of Research (A)    SP23
# 2           ANAR 111 - Foundations of Archaeology (A)    SP23
# 3        ANAR 115 - Coastal Geomorphology/Environ (A)    SP23
# 4       ANAR 155 - Stdy Abrd: Ancient Mesoamerica (A)    SP23
# ...                                               ...     ...
# 63358  VIS 105D  - Aesthetics/Chinese Calligraphy (A)    SU07
# 63359  VIS 106A  - Painting:  Image Making        (A)    SU07
# 63360  VIS 194S  - Fantasy In Film                (A)    SU07
# 63361     VIS 22 - Formations of Modern Art       (A)    SU07
# 63362     VIS 60 - Introduction to Photography    (A)    SU07
#
#        Total Enrolled in Course  Total CAPEs Given  \
# 0                            66                 48
# 1                            20                  7
# 2                            16                  3
# 3                            26                  6
# 4                            22                  9
# ...                         ...                ...
# 63358                        17                 13
# 63359                        16                 14
# 63360                        80                 57
# 63361                        40                 33
# 63362                        19                 18
#
#       Percentage Recommended Class Percentage Recommended Professor  \
# 0                            93.5%                           100.0%
# 1                           100.0%                           100.0%
# 2                           100.0%                           100.0%
# 3                           100.0%                            83.3%
# 4                           100.0%                           100.0%
# ...                            ...                              ...
# 63358                       100.0%                           100.0%
# 63359                        92.9%                            92.9%
# 63360                        74.1%                            26.4%
# 63361                       100.0%                            96.7%
# 63362                       100.0%                            94.1%
#
#        Study Hours per Week Average Grade Expected Average Grade Received  \
# 0                      2.80              A- (3.84)              B+ (3.67)
# 1                      2.50              A- (3.86)              A- (3.92)
# 2                      3.83              B+ (3.67)                    NaN
# 3                      3.83              B+ (3.50)               B (3.07)
# 4                      5.17               A (4.00)               A (4.00)
# ...                     ...                    ...                    ...
# 63358                  2.33               A (4.00)                    NaN
# 63359                  7.21              A- (3.79)                    NaN
# 63360                  4.27               B (3.21)                    NaN
# 63361                  4.32              B+ (3.62)                    NaN
# 63362                 13.28              B+ (3.59)                    NaN
#
#                                          Evalulation URL
# 0      https://cape.ucsd.edu/CAPEReport.aspx?sectioni...
# 1      https://cape.ucsd.edu/CAPEReport.aspx?sectioni...
# 2      https://cape.ucsd.edu/CAPEReport.aspx?sectioni...
# 3      https://cape.ucsd.edu/CAPEReport.aspx?sectioni...
# 4      https://cape.ucsd.edu/CAPEReport.aspx?sectioni...
# ...                                                  ...
# 63358  https://cape.ucsd.edu/scripts/detailedStats.as...
# 63359  https://cape.ucsd.edu/scripts/detailedStats.as...
# 63360  https://cape.ucsd.edu/scripts/detailedStats.as...
# 63361  https://cape.ucsd.edu/scripts/detailedStats.as...
# 63362  https://cape.ucsd.edu/scripts/detailedStats.as...
#
# [63363 rows x 11 columns]

# %%
from selenium import webdriver
from selenium.webdriver.support.ui import Select
from selenium.webdriver.common.keys import Keys

import time

try:
    import urllib.request as urllib2
except ImportError:
    import urllib2

# %%
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.chrome.options import Options

chrome_options = Options()
chrome_options.add_argument("--headless")  # Run without UI
chrome_options.add_argument("--disable-gpu")  # Disable GPU for headless environments
chrome_options.add_argument("--no-sandbox")  # Disable sandboxing
chrome_options.add_argument("--disable-dev-shm-usage")

# %%
driver = webdriver.Chrome()

# %%
url = 'https://ucannualwage.ucop.edu/wage/'
driver.get(url)
time.sleep(1)

# %%
from selenium.webdriver.common.by import By

def get_df(location, last, first):
    #create empty dataframe to hold info
    new_df = pd.DataFrame(columns=['Year', 'Location', 'First Name', 'Last Name', 'Title', 'Gross Pay', 'Regular Pay', 'Overtime Pay', 'Other Pay'])
    
    #find the table in the html by xpath
    table_body = driver.find_element(By.XPATH, '//*[@id="list2"]')
    
    #go through all entries (some will not be relevant)
    entries = table_body.find_elements(By.TAG_NAME, 'tr')
    if len(entries) == 0: 
        #if there are no entries for the person, then their salary is not available. Create empty row
        new_row = {'Year':"", 'Location':location, 'First Name':first, 'Last Name':last, 'Title':"", 'Gross Pay':"", 'Regular Pay':"", 'Overtime Pay':"", 'Other Pay':""}
        new_df = pd.concat([new_df, pd.DataFrame([new_row])], ignore_index=True, sort=False)
    else:
        #if there are entries, then add a row
        for i in range(0, len(entries)):
            cols = entries[i].find_elements(By.TAG_NAME, 'td')
            table_row = ''

            #assign the column data to header names
            #if the page does not load quick enough, let the program sleep for 0.5 seconds.
            #continue to scrape data until found.
            while True:
                try:
                    year = cols[2].text
                    location = cols[3].text
                    firstname = cols[4].text
                    lastname = cols[5].text
                    title = cols[6].text
                    grossp = cols[7].text
                    regp = cols[8].text
                    overp = cols[9].text
                    otherp = cols[10].text
                    break;
                except:
                    time.sleep(1)
                    continue;
             
            #avoid duplicates by making sure the names match before adding to df
            if firstname.split(' ')[0] != first or lastname.split(' ')[0] != last:
                continue
            
            #create a new row with the above values and add to the temporary dataframe
            new_row = {'Year':year, 'Location':location, 'First Name':firstname, 'Last Name':lastname, 'Title':title, 'Gross Pay':grossp, 'Regular Pay':regp, 'Overtime Pay':overp, 'Other Pay':otherp}
            new_df = pd.concat([new_df, pd.DataFrame([new_row])], ignore_index=True, sort=False)
        
    #return the dataframe
    return new_df

# %%
from selenium.webdriver.common.by import By

def search_prof_salary(location, last, first, year):
    
    #input location into form (we are looking for San Diego only)
    grade_dropdown = Select(driver.find_element(By.ID, "location"))
    grade_dropdown.select_by_value(location)

    #input year into form
    year_dropdown = Select(driver.find_element(By.ID, 'year'))
    year_dropdown.select_by_value(year)
    
    #input lastname into form
    driver.find_element(By.ID, 'lastname').send_keys(last)
    
    #input firstname into form
    driver.find_element(By.ID, 'firstname').send_keys(first)
    
    driver.find_element(By.XPATH, '//*[@id="searchButton"]').click()
    
    #allow the data to load
    time.sleep(3)
    
    #clear the text boxes
    driver.find_element(By.ID, 'lastname').clear()
    driver.find_element(By.ID, 'firstname').clear()
    
    #now we scrape the table and return the dataframe
    return get_df(location, last, first)

# %%
rady_profs = capes_dat[capes_dat['Course'].str.contains('MGT')]
rady_profs
# Out:
#                   Instructor                                          Course  \
# 761         Wilbur Kenneth C                MGT 100 - Customer Analytics (A)
# 762         Wilbur Kenneth C                MGT 100 - Customer Analytics (B)
# 763         Wilbur Kenneth C                MGT 100 - Customer Analytics (C)
# 764        Ehrich Kristine R    MGT 103 - Product Marketing & Management (A)
# 765        Ehrich Kristine R    MGT 103 - Product Marketing & Management (B)
# ...                      ...                                             ...
# 61777        Foit Delbert F.  MGT 121A  - Innovation to Market A         (A)
# 61778         August Terence    MGT 174 - Supply Chain & Operations Mgt  (A)
# 61779     Sullivan Robert S.    MGT 181 - Enterprise Finance             (A)
# 62754  Liersch Michael James    MGT 164 - Organizational Leadership      (A)
# 62755            Erat Sanjiv    MGT 172 - Business Project Management    (A)
#
#       Quarter  Total Enrolled in Course  Total CAPEs Given  \
# 761      SP23                        88                 78
# 762      SP23                        89                 83
# 763      SP23                        86                 83
# 764      SP23                        85                 65
# 765      SP23                        85                 72
# ...       ...                       ...                ...
# 61777    WI08                        64                 44
# 61778    WI08                        52                 46
# 61779    WI08                        40                 26
# 62754    FA07                        66                 55
# 62755    FA07                        64                 50
#
#       Percentage Recommended Class Percentage Recommended Professor  \
# 761                          78.2%                            79.5%
# 762                          77.1%                            80.7%
# 763                          75.9%                            71.1%
# 764                          95.4%                            93.8%
# 765                          97.2%                            98.6%
# ...                            ...                              ...
# 61777                        95.3%                            86.0%
# 61778                       100.0%                           100.0%
# 61779                       100.0%                           100.0%
# 62754                       100.0%                           100.0%
# 62755                        93.8%                            93.8%
#
#        Study Hours per Week Average Grade Expected Average Grade Received  \
# 761                    6.97               B (3.23)               B (3.15)
# 762                    6.99              B+ (3.36)               B (3.15)
# 763                    7.70              B+ (3.35)               B (3.16)
# 764                    3.98              B+ (3.40)               B (3.03)
# 765                    3.78              B+ (3.36)               B (3.14)
# ...                     ...                    ...                    ...
# 61777                  3.20              A- (3.90)              B+ (3.54)
# 61778                  5.86              B+ (3.50)               B (3.25)
# 61779                  5.27               B (3.16)               B (3.20)
# 62754                  2.93              B+ (3.58)              B+ (3.39)
# 62755                  3.42              A- (3.79)              B+ (3.45)
#
#                                          Evalulation URL
# 761    https://cape.ucsd.edu/CAPEReport.aspx?sectioni...
# 762    https://cape.ucsd.edu/CAPEReport.aspx?sectioni...
# 763    https://cape.ucsd.edu/CAPEReport.aspx?sectioni...
# 764    https://cape.ucsd.edu/CAPEReport.aspx?sectioni...
# 765    https://cape.ucsd.edu/CAPEReport.aspx?sectioni...
# ...                                                  ...
# 61777  https://cape.ucsd.edu/scripts/detailedStats.as...
# 61778  https://cape.ucsd.edu/scripts/detailedStats.as...
# 61779  https://cape.ucsd.edu/scripts/detailedStats.as...
# 62754  https://cape.ucsd.edu/scripts/detailedStats.as...
# 62755  https://cape.ucsd.edu/scripts/detailedStats.as...
#
# [2150 rows x 11 columns]

# %%
subset_2023 = rady_profs[rady_profs['Quarter'].str.contains('23')]
subset_2022 = rady_profs[rady_profs['Quarter'].str.contains('22')]
subset_2021 = rady_profs[rady_profs['Quarter'].str.contains('21')]
subset_2020 = rady_profs[rady_profs['Quarter'].str.contains('20')]

# %%
unique_instructors_2023 = subset_2023['Instructor'].unique()
unique_instructors_2022 = subset_2022['Instructor'].unique()
unique_instructors_2021 = subset_2021['Instructor'].unique()
unique_instructors_2020 = subset_2020['Instructor'].unique()

# %%
df = pd.DataFrame(unique_instructors_2023, columns=['Instructor'])
df_names = df.iloc[:, 0]

df_prof_salary_2023 = pd.DataFrame() #create empty dataframe

for name in df_names:
    chunks_fl = name.split(',') #split the name into first-middle and last
    chunks_lm = chunks_fl[0].split(' ') #split the last name
    chunks_fm = chunks_fl[-1].split(' ') #split the first name 

    last = chunks_lm[0].upper() #get only one last name
    first = chunks_fm[1].upper() #get only one first name
    
    df_prof_salary_2023 = pd.concat([df_prof_salary_2023, search_prof_salary("San Diego", last, first, '2023')], ignore_index=True)

# %%
df = pd.DataFrame(unique_instructors_2022, columns=['Instructor'])
df_names = df.iloc[:, 0]

df_prof_salary_2022 = pd.DataFrame() #create empty dataframe

for name in df_names:
    chunks_fl = name.split(',') #split the name into first-middle and last
    chunks_lm = chunks_fl[0].split(' ') #split the last name
    chunks_fm = chunks_fl[-1].split(' ') #split the first name 

    last = chunks_lm[0].upper() #get only one last name
    first = chunks_fm[1].upper() #get only one first name
    
    df_prof_salary_2022 = pd.concat([df_prof_salary_2022, search_prof_salary("San Diego", last, first, '2022')], ignore_index=True)

# %%
df = pd.DataFrame(unique_instructors_2021, columns=['Instructor'])
df_names = df.iloc[:, 0]

df_prof_salary_2021 = pd.DataFrame() #create empty dataframe

for name in df_names:
    chunks_fl = name.split(',') #split the name into first-middle and last
    chunks_lm = chunks_fl[0].split(' ') #split the last name
    chunks_fm = chunks_fl[-1].split(' ') #split the first name 

    last = chunks_lm[0].upper() #get only one last name
    first = chunks_fm[1].upper() #get only one first name
    
    df_prof_salary_2021 = pd.concat([df_prof_salary_2021, search_prof_salary("San Diego", last, first, '2021')], ignore_index=True)

# %%
df = pd.DataFrame(unique_instructors_2020, columns=['Instructor'])
df_names = df.iloc[:, 0]

df_prof_salary_2020 = pd.DataFrame() #create empty dataframe

for name in df_names:
    chunks_fl = name.split(',') #split the name into first-middle and last
    chunks_lm = chunks_fl[0].split(' ') #split the last name
    chunks_fm = chunks_fl[-1].split(' ') #split the first name 

    last = chunks_lm[0].upper() #get only one last name
    first = chunks_fm[1].upper() #get only one first name
    
    df_prof_salary_2020 = pd.concat([df_prof_salary_2020, search_prof_salary("San Diego", last, first, '2020')], ignore_index=True)

# %%
df_prof_salary = pd.concat([df_prof_salary_2023, df_prof_salary_2022, df_prof_salary_2021, df_prof_salary_2020])

# %%
df_prof_salary = df_prof_salary[(df_prof_salary['Gross Pay'] != '')]
df_prof_salary
# Out:
#     Year   Location   First Name     Last Name                   Title  \
# 1   2023  San Diego     KRISTINE        EHRICH      LECT-AY-CONTINUING
# 2   2023  San Diego      KENNETH         BATES                 LECT-AY
# 4   2023  San Diego   TYAGARAJAN  SOMASUNDARAM          VIS ASSOC PROF
# 5   2023  San Diego      CARSTEN    ZIMMERMANN          VIS ASSOC PROF
# 7   2023  San Diego          JON      ANDERSON             LECT-AY-1/9
# ..   ...        ...          ...           ...                     ...
# 42  2020  San Diego  CHRISTOPHER         GOPAL  LECT IN SUMMER SESSION
# 43  2020  San Diego       EDWIGE       CHEYNEL      ASST PROF-AY-B/E/E
# 44  2020  San Diego        KEVIN           ZHU           PROF-AY-B/E/E
# 45  2020  San Diego       JEREMY      BERTOMEU     ASSOC PROF-AY-B/E/E
# 46  2020  San Diego        SAT P      PARASHAR             LECT-AY-1/9
#
#      Gross Pay Regular Pay Overtime Pay  Other Pay
# 1   195,886.00  167,724.00         0.00  28,162.00
# 2   141,228.00  141,228.00         0.00       0.00
# 4   129,708.00  129,708.00         0.00       0.00
# 5   195,995.00  182,395.00         0.00  13,600.00
# 7    51,528.00   51,528.00         0.00       0.00
# ..         ...         ...          ...        ...
# 42   56,288.00   49,527.00         0.00   6,761.00
# 43  171,725.00  162,225.00         0.00   9,500.00
# 44  289,553.00  222,503.00         0.00  67,050.00
# 45  167,475.00  167,475.00         0.00       0.00
# 46   32,179.00   32,179.00         0.00       0.00
#
# [179 rows x 9 columns]

# %%
df_prof_salary.to_csv('prof_salary_data.csv', index=False)

# %%
subset_dat = pd.concat([subset_2023, subset_2022, subset_2021, subset_2020])
subset_dat.head()
# Out:
#             Instructor                                        Course Quarter  \
# 761   Wilbur Kenneth C              MGT 100 - Customer Analytics (A)    SP23
# 762   Wilbur Kenneth C              MGT 100 - Customer Analytics (B)    SP23
# 763   Wilbur Kenneth C              MGT 100 - Customer Analytics (C)    SP23
# 764  Ehrich Kristine R  MGT 103 - Product Marketing & Management (A)    SP23
# 765  Ehrich Kristine R  MGT 103 - Product Marketing & Management (B)    SP23
#
#      Total Enrolled in Course  Total CAPEs Given Percentage Recommended Class  \
# 761                        88                 78                        78.2%
# 762                        89                 83                        77.1%
# 763                        86                 83                        75.9%
# 764                        85                 65                        95.4%
# 765                        85                 72                        97.2%
#
#     Percentage Recommended Professor  Study Hours per Week  \
# 761                            79.5%                  6.97
# 762                            80.7%                  6.99
# 763                            71.1%                  7.70
# 764                            93.8%                  3.98
# 765                            98.6%                  3.78
#
#     Average Grade Expected Average Grade Received  \
# 761               B (3.23)               B (3.15)
# 762              B+ (3.36)               B (3.15)
# 763              B+ (3.35)               B (3.16)
# 764              B+ (3.40)               B (3.03)
# 765              B+ (3.36)               B (3.14)
#
#                                        Evalulation URL
# 761  https://cape.ucsd.edu/CAPEReport.aspx?sectioni...
# 762  https://cape.ucsd.edu/CAPEReport.aspx?sectioni...
# 763  https://cape.ucsd.edu/CAPEReport.aspx?sectioni...
# 764  https://cape.ucsd.edu/CAPEReport.aspx?sectioni...
# 765  https://cape.ucsd.edu/CAPEReport.aspx?sectioni...

# %%
subset_dat.to_csv('rady_capes.csv', index=False)

# %%
subset_dat['last_name'] = subset_dat['Instructor'].str.split(" ").apply(lambda x: x[0].upper())
subset_dat['year_tail'] = subset_dat['Quarter'].str[2:]
subset_dat.head()
# Out:
#             Instructor                                        Course Quarter  \
# 761   Wilbur Kenneth C              MGT 100 - Customer Analytics (A)    SP23
# 762   Wilbur Kenneth C              MGT 100 - Customer Analytics (B)    SP23
# 763   Wilbur Kenneth C              MGT 100 - Customer Analytics (C)    SP23
# 764  Ehrich Kristine R  MGT 103 - Product Marketing & Management (A)    SP23
# 765  Ehrich Kristine R  MGT 103 - Product Marketing & Management (B)    SP23
#
#      Total Enrolled in Course  Total CAPEs Given Percentage Recommended Class  \
# 761                        88                 78                        78.2%
# 762                        89                 83                        77.1%
# 763                        86                 83                        75.9%
# 764                        85                 65                        95.4%
# 765                        85                 72                        97.2%
#
#     Percentage Recommended Professor  Study Hours per Week  \
# 761                            79.5%                  6.97
# 762                            80.7%                  6.99
# 763                            71.1%                  7.70
# 764                            93.8%                  3.98
# 765                            98.6%                  3.78
#
#     Average Grade Expected Average Grade Received  \
# 761               B (3.23)               B (3.15)
# 762              B+ (3.36)               B (3.15)
# 763              B+ (3.35)               B (3.16)
# 764              B+ (3.40)               B (3.03)
# 765              B+ (3.36)               B (3.14)
#
#                                        Evalulation URL last_name year_tail
# 761  https://cape.ucsd.edu/CAPEReport.aspx?sectioni...    WILBUR        23
# 762  https://cape.ucsd.edu/CAPEReport.aspx?sectioni...    WILBUR        23
# 763  https://cape.ucsd.edu/CAPEReport.aspx?sectioni...    WILBUR        23
# 764  https://cape.ucsd.edu/CAPEReport.aspx?sectioni...    EHRICH        23
# 765  https://cape.ucsd.edu/CAPEReport.aspx?sectioni...    EHRICH        23

# %%
df_prof_salary['year_tail'] = df_prof_salary['Year'].str[2:]
df_prof_salary.head()
# Out:
#    Year   Location  First Name     Last Name               Title   Gross Pay  \
# 1  2023  San Diego    KRISTINE        EHRICH  LECT-AY-CONTINUING  195,886.00
# 2  2023  San Diego     KENNETH         BATES             LECT-AY  141,228.00
# 4  2023  San Diego  TYAGARAJAN  SOMASUNDARAM      VIS ASSOC PROF  129,708.00
# 5  2023  San Diego     CARSTEN    ZIMMERMANN      VIS ASSOC PROF  195,995.00
# 7  2023  San Diego         JON      ANDERSON         LECT-AY-1/9   51,528.00
#
#   Regular Pay Overtime Pay  Other Pay year_tail
# 1  167,724.00         0.00  28,162.00        23
# 2  141,228.00         0.00       0.00        23
# 4  129,708.00         0.00       0.00        23
# 5  182,395.00         0.00  13,600.00        23
# 7   51,528.00         0.00       0.00        23

# %%
capes_salary_merge = subset_dat.merge(df_prof_salary, left_on=['last_name', 'year_tail'], right_on=['Last Name', 'year_tail'], how='left')
capes_salary_merge
# Out:
#               Instructor                                        Course  \
# 0       Wilbur Kenneth C              MGT 100 - Customer Analytics (A)
# 1       Wilbur Kenneth C              MGT 100 - Customer Analytics (B)
# 2       Wilbur Kenneth C              MGT 100 - Customer Analytics (C)
# 3      Ehrich Kristine R  MGT 103 - Product Marketing & Management (A)
# 4      Ehrich Kristine R  MGT 103 - Product Marketing & Management (B)
# ..                   ...                                           ...
# 991  Wagner Timothy Ryan         MGT 3 - Quant Methods in Business (A)
# 992    Levkoff Steven B.              MGT 4 - Financial Accounting (A)
# 993     Pecore Joseph P.         MGT 45 - Principles of Accounting (A)
# 994    Houskeeper Robert             MGT 5 - Managerial Accounting (A)
# 995    Houskeeper Robert             MGT 5 - Managerial Accounting (B)
#
#     Quarter  Total Enrolled in Course  Total CAPEs Given  \
# 0      SP23                        88                 78
# 1      SP23                        89                 83
# 2      SP23                        86                 83
# 3      SP23                        85                 65
# 4      SP23                        85                 72
# ..      ...                       ...                ...
# 991    WI20                        53                 26
# 992    WI20                         9                  3
# 993    WI20                       141                131
# 994    WI20                        97                 74
# 995    WI20                       155                129
#
#     Percentage Recommended Class Percentage Recommended Professor  \
# 0                          78.2%                            79.5%
# 1                          77.1%                            80.7%
# 2                          75.9%                            71.1%
# 3                          95.4%                            93.8%
# 4                          97.2%                            98.6%
# ..                           ...                              ...
# 991                        88.0%                            88.0%
# 992                        66.7%                            66.7%
# 993                        96.9%                            96.9%
# 994                        83.6%                            83.6%
# 995                        89.0%                            92.1%
#
#      Study Hours per Week Average Grade Expected Average Grade Received  ...  \
# 0                    6.97               B (3.23)               B (3.15)  ...
# 1                    6.99              B+ (3.36)               B (3.15)  ...
# 2                    7.70              B+ (3.35)               B (3.16)  ...
# 3                    3.98              B+ (3.40)               B (3.03)  ...
# 4                    3.78              B+ (3.36)               B (3.14)  ...
# ..                    ...                    ...                    ...  ...
# 991                  4.26              B+ (3.59)               B (3.21)  ...
# 992                  5.17              C+ (2.67)                    NaN  ...
# 993                  5.75              B+ (3.47)              B+ (3.34)  ...
# 994                  4.61               B (3.16)              B- (2.92)  ...
# 995                  4.11              B+ (3.43)               B (3.22)  ...
#
#     year_tail  Year   Location First Name   Last Name               Title  \
# 0          23   NaN        NaN        NaN         NaN                 NaN
# 1          23   NaN        NaN        NaN         NaN                 NaN
# 2          23   NaN        NaN        NaN         NaN                 NaN
# 3          23  2023  San Diego   KRISTINE      EHRICH  LECT-AY-CONTINUING
# 4          23  2023  San Diego   KRISTINE      EHRICH  LECT-AY-CONTINUING
# ..        ...   ...        ...        ...         ...                 ...
# 991        20  2020  San Diego    TIMOTHY      WAGNER             LECT-AY
# 992        20  2020  San Diego     STEVEN     LEVKOFF  LECT-AY-CONTINUING
# 993        20  2020  San Diego     JOSEPH      PECORE  LECT-AY-CONTINUING
# 994        20  2020  San Diego     ROBERT  HOUSKEEPER  LECT-AY-CONTINUING
# 995        20  2020  San Diego     ROBERT  HOUSKEEPER  LECT-AY-CONTINUING
#
#       Gross Pay Regular Pay Overtime Pay  Other Pay
# 0           NaN         NaN          NaN        NaN
# 1           NaN         NaN          NaN        NaN
# 2           NaN         NaN          NaN        NaN
# 3    195,886.00  167,724.00         0.00  28,162.00
# 4    195,886.00  167,724.00         0.00  28,162.00
# ..          ...         ...          ...        ...
# 991   34,493.00   34,493.00         0.00       0.00
# 992  111,044.00   88,717.00         0.00  22,327.00
# 993  188,561.00  174,103.00         0.00  14,458.00
# 994  163,335.00  139,603.00         0.00  23,732.00
# 995  163,335.00  139,603.00         0.00  23,732.00
#
# [996 rows x 22 columns]

# %%
capes_salary_merge.to_csv('merged_salary_capes.csv', index=False)

# %%
rady_dat = pd.read_csv('data/rady_capes.csv')
salary_dat = pd.read_csv('data/prof_salary_data.csv')

# %%
rady_dat
# Out:
#               Instructor                                        Course  \
# 0       Wilbur Kenneth C              MGT 100 - Customer Analytics (A)
# 1       Wilbur Kenneth C              MGT 100 - Customer Analytics (B)
# 2       Wilbur Kenneth C              MGT 100 - Customer Analytics (C)
# 3      Ehrich Kristine R  MGT 103 - Product Marketing & Management (A)
# 4      Ehrich Kristine R  MGT 103 - Product Marketing & Management (B)
# ..                   ...                                           ...
# 876  Wagner Timothy Ryan         MGT 3 - Quant Methods in Business (A)
# 877    Levkoff Steven B.              MGT 4 - Financial Accounting (A)
# 878     Pecore Joseph P.         MGT 45 - Principles of Accounting (A)
# 879    Houskeeper Robert             MGT 5 - Managerial Accounting (A)
# 880    Houskeeper Robert             MGT 5 - Managerial Accounting (B)
#
#     Quarter  Total Enrolled in Course  Total CAPEs Given  \
# 0      SP23                        88                 78
# 1      SP23                        89                 83
# 2      SP23                        86                 83
# 3      SP23                        85                 65
# 4      SP23                        85                 72
# ..      ...                       ...                ...
# 876    WI20                        53                 26
# 877    WI20                         9                  3
# 878    WI20                       141                131
# 879    WI20                        97                 74
# 880    WI20                       155                129
#
#     Percentage Recommended Class Percentage Recommended Professor  \
# 0                          78.2%                            79.5%
# 1                          77.1%                            80.7%
# 2                          75.9%                            71.1%
# 3                          95.4%                            93.8%
# 4                          97.2%                            98.6%
# ..                           ...                              ...
# 876                        88.0%                            88.0%
# 877                        66.7%                            66.7%
# 878                        96.9%                            96.9%
# 879                        83.6%                            83.6%
# 880                        89.0%                            92.1%
#
#      Study Hours per Week Average Grade Expected Average Grade Received  \
# 0                    6.97               B (3.23)               B (3.15)
# 1                    6.99              B+ (3.36)               B (3.15)
# 2                    7.70              B+ (3.35)               B (3.16)
# 3                    3.98              B+ (3.40)               B (3.03)
# 4                    3.78              B+ (3.36)               B (3.14)
# ..                    ...                    ...                    ...
# 876                  4.26              B+ (3.59)               B (3.21)
# 877                  5.17              C+ (2.67)                    NaN
# 878                  5.75              B+ (3.47)              B+ (3.34)
# 879                  4.61               B (3.16)              B- (2.92)
# 880                  4.11              B+ (3.43)               B (3.22)
#
#                                        Evalulation URL
# 0    https://cape.ucsd.edu/CAPEReport.aspx?sectioni...
# 1    https://cape.ucsd.edu/CAPEReport.aspx?sectioni...
# 2    https://cape.ucsd.edu/CAPEReport.aspx?sectioni...
# 3    https://cape.ucsd.edu/CAPEReport.aspx?sectioni...
# 4    https://cape.ucsd.edu/CAPEReport.aspx?sectioni...
# ..                                                 ...
# 876  https://cape.ucsd.edu/CAPEReport.aspx?sectioni...
# 877  https://cape.ucsd.edu/CAPEReport.aspx?sectioni...
# 878  https://cape.ucsd.edu/CAPEReport.aspx?sectioni...
# 879  https://cape.ucsd.edu/CAPEReport.aspx?sectioni...
# 880  https://cape.ucsd.edu/CAPEReport.aspx?sectioni...
#
# [881 rows x 11 columns]
